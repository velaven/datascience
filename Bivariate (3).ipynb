# %%
import pandas as pd

# %%
dataset=pd.read_csv("preplacementdataNew.csv")

# %%
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3      4.0  56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  215.0  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
# ...

# %%
dataset.isnull()
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p  salary  gender  ssc_b  \
# 0    False  False  False     False    False  False   False   False  False
# 1    False  False  False     False    False  False   False   False  False
# 2    False  False  False     False    False  False   False   False  False
# 3    False  False  False     False    False  False   False   False  False
# 4    False  False  False     False    False  False   False   False  False
# ..     ...    ...    ...       ...      ...    ...     ...     ...    ...
# 210  False  False  False     False    False  False   False   False  False
# 211  False  False  False     False    False  False   False   False  False
# 212  False  False  False     False    False  False   False   False  False
# 213  False  False  False     False    False  False   False   False  False
# 214  False  False  False     False    False  False   False   False  False
#
#      hsc_b  hsc_s  degree_t  workex  specialisation  status
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
dataset.cov()
# Out:
#                  sl_no          ssc_p          hsc_p       degree_p  \
# sl_no      3870.000000     -52.641355     -58.106028     -40.413645
# ssc_p       -52.641355     117.228377      60.348373      42.897137
# hsc_p       -58.106028      60.348373     118.755706      34.819820
# degree_p    -40.413645      42.897137      34.819820      54.151103
# etest_p      52.556168      37.659225      35.461678      21.929469
# mba_p         8.102336      24.535952      22.555846      17.272020
# salary    24490.654206  901754.893936  763359.777657  465131.504238
#
#                 etest_p          mba_p        salary
# sl_no         52.556168       8.102336  2.449065e+04
# ssc_p         37.659225      24.535952  9.017549e+05
# hsc_p         35.461678      22.555846  7.633598e+05
# degree_p      21.929469      17.272020  4.651315e+05
# etest_p      176.251018      16.886973  3.842344e+05
# mba_p         16.886973      34.028376  1.262455e+05
# ...

# %%
#etest_p with mba_p have positive covariance
#mba_p with etest_p have positive covariance
#degree_p with etest_p and mba_p have positive covariance

# %%
dataset.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
#mba_p and salary have 0.131926 value lesser positive correlation directly propotional 13%

# %%
dataset.drop('sl_no',inplace=True,axis=1)

# %%
dataset
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0    67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1    79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2    65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3    56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4    85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...       ...      ...    ...       ...    ...      ...
# 210  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(dataset)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calc_vif(X):
    #calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return(vif)

# %%
calc_vif(dataset[["ssc_p","hsc_p","degree_p","etest_p","mba_p","salary"]])
# Out:
#   variables         VIF
# 0     ssc_p   76.496603
# 1     hsc_p   58.972066
# 2  degree_p  113.299298
# 3   etest_p   32.679659
# 4     mba_p  114.025972
# 5    salary    3.931112

# %%
calc_vif(dataset[["etest_p","salary"]])
# Out:
#   variables       VIF
# 0   etest_p  2.745261
# 1    salary  2.745261

# %%
#from above two data to create model

# %% [markdown]
# # Independent sample-Unpaired T Test
# Different Group(Male,Female) but same contion(salary)

# %%
dataset=pd.read_csv("placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset[dataset["gender"]=="F"]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 6        7      F  46.00   Others   49.2   Others  Commerce      79.0
# 12      13      F  47.00  Central   55.0   Others   Science      65.0
# 13      14      F  77.00  Central   87.0  Central  Commerce      59.0
# 15      16      F  65.00  Central   75.0  Central  Commerce      69.0
# 17      18      F  55.00  Central   67.0  Central  Commerce      64.0
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 197    198      F  83.96   Others   53.0   Others   Science      91.0
# 198    199      F  67.00  Central   70.0  Central  Commerce      65.0
# 204    205      F  74.00   Others   73.0   Others  Commerce      73.0
# 208    209      F  43.00  Central   60.0   Others   Science      65.0
# 213    214      F  74.00   Others   66.0   Others  Commerce      58.0
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset[dataset['gender']=="M"]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset[dataset['gender']=='M']['salary']
# Out:
# 0      270000.0
# 1      200000.0
# 2      250000.0
# 3           NaN
# 4      425000.0
#          ...
# 209    216000.0
# 210    400000.0
# 211    275000.0
# 212    295000.0
# 214         NaN
# Name: salary, Length: 139, dtype: float64

# %%
dataset[dataset['gender']=='F']['salary']
# Out:
# 13     218000.0
# 15     200000.0
# 21     393000.0
# 22     360000.0
# 23     300000.0
# 30     250000.0
# 32     278000.0
# 33     260000.0
# 35     300000.0
# 37     320000.0
# 38     240000.0
# 40     287000.0
# 44     200000.0
# 50     200000.0
# 54     216000.0
# 62     240000.0
# 76     230000.0
# 80     240000.0
# 85     400000.0
# 88     210000.0
# 89     210000.0
# 90     300000.0
# 92     230000.0
# 96     300000.0
# 98     220000.0
# 102    300000.0
# 110    250000.0
# 113    280000.0
# 115    216000.0
# 121    250000.0
# 122    236000.0
# 125    350000.0
# 126    210000.0
# 127    250000.0
# 131    360000.0
# 134    250000.0
# 135    200000.0
# 138    250000.0
# 148    240000.0
# 152    240000.0
# 164    250000.0
# 176    220000.0
# 177    650000.0
# 185    252000.0
# 193    300000.0
# 197    260000.0
# 204    210000.0
# 213    204000.0
# Name: salary, dtype: float64

# %%
dataset[dataset['hsc_p']=='others']['salary']
# Out:
# Series([], Name: salary, dtype: float64)

# %%
dataset[dataset['hsc_p']=='central']['salary']
# Out:
# Series([], Name: salary, dtype: float64)

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
male = dataset[dataset['gender']=='M']['salary']
female = dataset[dataset['gender']=='F']['salary']
#print(male)
ttest_ind(male, female)
# Out:
# Ttest_indResult(statistic=1.9448521615505496, pvalue=0.053714668806405776)

# %%
dataset=pd.read_csv("placement.csv")

# %%
dataset[dataset['hsc_b']=='Others']["salary"]
# Out:
# 0      270000.0
# 1      200000.0
# 5           NaN
# 6           NaN
# 12          NaN
#          ...
# 210    400000.0
# 211    275000.0
# 212    295000.0
# 213    204000.0
# 214         NaN
# Name: salary, Length: 131, dtype: float64

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
Others = dataset[dataset['hsc_b']=='Others']['salary']
Central = dataset[dataset['hsc_b']=='Central']['salary']
ttest_ind(Others, Central)
# Out:
# Ttest_indResult(statistic=-0.09122184544225677, pvalue=0.9274413548271779)

# %%
### Dependent Sample
#Same Group(Male) but Different Condition(ssc_p,hsc_p)

# %%
from scipy.stats import ttest_ind
#dataset=dataset.dropna()
male = dataset[dataset['gender']=='M']['ssc_p']
male1 = dataset[dataset['gender']=='M']['hsc_p']
#print(male)
ttest_ind(male, male1)
# Out:
# Ttest_indResult(statistic=0.700911773352417, pvalue=0.48418096265917276)

# %% [markdown]
# #same group(commerce) but different condition(mba_p,etest_p)

# %%
from scipy.stats import ttest_rel
#dataset=dataset.dropna()
Commerce = dataset[dataset['hsc_s']=='Commerce']['mba_p']
Commerce1 = dataset[dataset['hsc_s']=='Commerce']['etest_p']
ttest_rel(Commerce, Commerce1)
# Out:
# Ttest_relResult(statistic=-7.561268876092879, pvalue=6.62578075563851e-11)

# %%
from scipy.stats import ttest_rel
#dataset=dataset.dropna()
science = dataset[dataset['hsc_s']=='Science']['mba_p']
science1 = dataset[dataset['hsc_s']=='Science']['etest_p']
#print(science)
ttest_rel(science, science1)
# Out:
# Ttest_relResult(statistic=-6.655911515627904, pvalue=8.44263724732204e-09)

# %%
#Hypothesis Testing

# %%
#statement:Test whether ssc_p of male and Hsc_p of Male is same

# %%
#Null hypothesis=There is no similarity between 10th pass mark of male and 12th pass mark of male

# %%
from scipy.stats import ttest_rel
#dataset=dataset.dropna()
male = dataset[dataset['gender']=='M']['ssc_p']
male1 = dataset[dataset['gender']=='M']['hsc_p']
#print(male)
ttest_rel(male, male1)
# Out:
# Ttest_relResult(statistic=0.881726473207718, pvalue=0.38006050142386005)

# %% [markdown]
# # Reject Null hypothesis p<0.05
# #accept Null Hypothesis and Reject Alternate hypothesis
# ANAVO:Analysis of Variance

# %%
import scipy.stats as stats
stats.f_oneway(dataset['ssc_p'],dataset['hsc_p'],dataset['degree_p'])
# Out:
# F_onewayResult(statistic=4.866998084927855, pvalue=0.008114829524764158)

# %%
#H0-there is no significant p<0.05
#H1-there is  significant difference these column

# %%
#TWO WAY ANAVO -the means of the first factor are equal,the means of the second factor are equal and there is no interaction between the two factor
#H0 population means of first factor (factorA) are equal.population means of second factor (factorB)are equal . -Null
#H1 Atleast one of the population means of the first factor (factorA) is different.and atleast one of the population means of the
#second factor (factorB)is different

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
#perform two way ANOVA 
Two_Way= ols('salary ~ ssc_p + hsc_p + degree_p+ssc_p*hsc_p*degree_p', data=dataset).fit()
Two=sm.stats.anova_lm(Two_Way, typ=2)

# %%
Two
# Out:
#                             sum_sq     df         F    PR(>F)
# ssc_p                 3.378030e+09    1.0  0.393923  0.531267
# hsc_p                 7.478456e+09    1.0  0.872086  0.351986
# degree_p              2.792485e+09    1.0  0.325640  0.569152
# ssc_p:hsc_p           1.619231e+10    1.0  1.888236  0.171597
# ssc_p:degree_p        3.120030e+07    1.0  0.003638  0.951988
# hsc_p:degree_p        6.980766e+10    1.0  8.140492  0.004986
# ssc_p:hsc_p:degree_p  1.250114e+09    1.0  0.145780  0.703180
# Residual              1.200551e+12  140.0       NaN       NaN
