# %%
import pandas as pd

# %%
dataset=pd.read_csv("preplacementdata.csv")

# %%
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00    55.00  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48    86.50  66.28  200000.0      M  Central
# 2      4.0  56.00  52.00     52.00    66.00  59.43       0.0    NaN      NaN
# 3      5.0  85.80  73.60     73.30    96.80  55.50  425000.0      M  Central
# 4      7.0  46.00  49.20     79.00    74.28  53.29       0.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 210  214.0  74.00  66.00     58.00    70.00  60.23  204000.0      M   Others
# 211  215.0  62.00  58.00     53.00    89.00  60.22       0.0      M   Others
# 212    NaN    NaN    NaN       NaN      NaN    NaN       NaN      M   Others
# 213    NaN    NaN    NaN       NaN      NaN    NaN       NaN      F   Others
# 214    NaN    NaN    NaN       NaN      NaN    NaN       NaN      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# 0     Others  Commerce   Sci&Tech     No         Mkt&HR      Placed
# 1     Others   Science   Sci&Tech    Yes        Mkt&Fin      Placed
# 2        NaN       NaN        NaN    NaN            NaN         NaN
# 3    Central   Science   Sci&Tech     No         Mkt&HR  Not Placed
# 4    Central  Commerce  Comm&Mgmt     No        Mkt&Fin      Placed
# ..       ...       ...        ...    ...            ...         ...
# 210   Others  Commerce  Comm&Mgmt     No        Mkt&Fin      Placed
# 211   Others   Science   Sci&Tech     No        Mkt&Fin      Placed
# 212   Others  Commerce  Comm&Mgmt    Yes        Mkt&Fin      Placed
# 213   Others  Commerce  Comm&Mgmt     No         Mkt&HR      Placed
# 214   Others   Science  Comm&Mgmt     No         Mkt&HR  Not Placed
#
# [215 rows x 15 columns]

# %%
dataset.isnull().sum()
# Out:
# sl_no             3
# ssc_p             3
# hsc_p             3
# degree_p          3
# etest_p           3
# mba_p             3
# salary            3
# gender            3
# ssc_b             3
# hsc_b             3
# hsc_s             3
# degree_t          3
# workex            3
# specialisation    3
# status            3
# dtype: int64

# %%
dataset.cov()
# Out:
#                  sl_no          ssc_p          hsc_p       degree_p  \
# sl_no      3774.920951     -57.871801     -60.166884     -39.072616
# ssc_p       -57.871801     117.997003      59.918137      43.381306
# hsc_p       -60.166884      59.918137     118.375003      35.064783
# degree_p    -39.072616      43.381306      35.064783      54.740135
# etest_p      55.541145      36.710758      33.448290      21.831332
# mba_p         0.243191      24.235567      22.132180      17.539761
# salary   -31322.543146  902654.824287  756293.867477  472298.415452
#
#                 etest_p          mba_p        salary
# sl_no         55.541145       0.243191 -3.132254e+04
# ssc_p         36.710758      24.235567  9.026548e+05
# hsc_p         33.448290      22.132180  7.562939e+05
# degree_p      21.831332      17.539761  4.722984e+05
# etest_p      175.576333      16.413497  3.699567e+05
# mba_p         16.413497      33.864256  1.191642e+05
# salary    369956.667263  119164.167933  2.409293e+10

# %%
#etest_p with mba_p have positive covariance
#mba_p with etest_p have positive covariance
#degree_p with etest_p and mba_p have positive covariance

# %%
dataset.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.086712 -0.090006 -0.085954  0.068223  0.000680 -0.003284
# ssc_p    -0.086712  1.000000  0.506982  0.539777  0.255050  0.383395  0.535354
# hsc_p    -0.090006  0.506982  1.000000  0.435600  0.232012  0.349561  0.447833
# degree_p -0.085954  0.539777  0.435600  1.000000  0.222687  0.407380  0.411262
# etest_p   0.068223  0.255050  0.232012  0.222687  1.000000  0.212862  0.179876
# mba_p     0.000680  0.383395  0.349561  0.407380  0.212862  1.000000  0.131926
# salary   -0.003284  0.535354  0.447833  0.411262  0.179876  0.131926  1.000000

# %%
#mba_p and salary have 0.131926 value lesser positive correlation directly propotional 13%

# %%
dataset.drop('sl_no',inplace=True,axis=1)

# %%
dataset
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0    67.00  91.00     58.00    55.00  58.80  270000.0      M   Others
# 1    79.33  78.33     77.48    86.50  66.28  200000.0      M  Central
# 2    56.00  52.00     52.00    66.00  59.43       0.0    NaN      NaN
# 3    85.80  73.60     73.30    96.80  55.50  425000.0      M  Central
# 4    46.00  49.20     79.00    74.28  53.29       0.0      M  Central
# ..     ...    ...       ...      ...    ...       ...    ...      ...
# 210  74.00  66.00     58.00    70.00  60.23  204000.0      M   Others
# 211  62.00  58.00     53.00    89.00  60.22       0.0      M   Others
# 212    NaN    NaN       NaN      NaN    NaN       NaN      M   Others
# 213    NaN    NaN       NaN      NaN    NaN       NaN      F   Others
# 214    NaN    NaN       NaN      NaN    NaN       NaN      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# 0     Others  Commerce   Sci&Tech     No         Mkt&HR      Placed
# 1     Others   Science   Sci&Tech    Yes        Mkt&Fin      Placed
# 2        NaN       NaN        NaN    NaN            NaN         NaN
# 3    Central   Science   Sci&Tech     No         Mkt&HR  Not Placed
# 4    Central  Commerce  Comm&Mgmt     No        Mkt&Fin      Placed
# ..       ...       ...        ...    ...            ...         ...
# 210   Others  Commerce  Comm&Mgmt     No        Mkt&Fin      Placed
# 211   Others   Science   Sci&Tech     No        Mkt&Fin      Placed
# 212   Others  Commerce  Comm&Mgmt    Yes        Mkt&Fin      Placed
# 213   Others  Commerce  Comm&Mgmt     No         Mkt&HR      Placed
# 214   Others   Science  Comm&Mgmt     No         Mkt&HR  Not Placed
#
# [215 rows x 14 columns]

# %%
import seaborn as sns

# %%
sns.pairplot(dataset)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calc_vif(X):
    #calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    return(vif)

# %%
calc_vif(dataset[["etest_p","salary"]])
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23128\1101114389.py in <module>
# ----> 1 calc_vif(dataset[["etest_p","salary"]])
#
# ~\AppData\Local\Temp\ipykernel_23128\3923381492.py in calc_vif(X)
#       4     vif = pd.DataFrame()
#       5     vif["variables"] = X.columns
# ----> 6     vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
#       7     return(vif)
#
# ~\AppData\Local\Temp\ipykernel_23128\3923381492.py in <listcomp>(.0)
#       4     vif = pd.DataFrame()
#       5     vif["variables"] = X.columns
# ----> 6     vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
#       7     return(vif)
#
# ~\anaconda3\envs\aiml\lib\site-packages\statsmodels\stats\outliers_influence.py in variance_inflation_factor(exog, exog_idx)
#     192     mask = np.arange(k_vars) != exog_idx
#     193     x_noti = exog[:, mask]
# --> 194     r_squared_i = OLS(x_i, x_noti).fit().rsquared
#     195     vif = 1. / (1. - r_squared_i)
#     196     return vif
#
# ~\anaconda3\envs\aiml\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     905             warnings.warn(msg, ValueWarning)
#     906         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 907                                   hasconst=hasconst, **kwargs)
#     908         if "weights" in self._init_keys:
#     909             self._init_keys.remove("weights")
#
# ~\anaconda3\envs\aiml\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     732             weights = weights.squeeze()
#     733         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 734                                   weights=weights, hasconst=hasconst, **kwargs)
#     735         nobs = self.exog.shape[0]
#     736         weights = self.weights
#
# ~\anaconda3\envs\aiml\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, **kwargs)
#     188     """
#     189     def __init__(self, endog, exog, **kwargs):
# --> 190         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     191         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#     192
#
# ~\anaconda3\envs\aiml\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#     265
#     266     def __init__(self, endog, exog=None, **kwargs):
# --> 267         super().__init__(endog, exog, **kwargs)
#     268         self.initialize()
#     269
#
# ~\anaconda3\envs\aiml\lib\site-packages\statsmodels\base\model.py in __init__(self, endog, exog, **kwargs)
#      91         hasconst = kwargs.pop('hasconst', None)
#      92         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 93                                       **kwargs)
#      94         self.k_constant = self.data.k_constant
#      95         self.exog = self.data.exog
#
# ~\anaconda3\envs\aiml\lib\site-packages\statsmodels\base\model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     130
#     131     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 132         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     133         # kwargs arrays could have changed, easier to just attach here
#     134         for key in kwargs:
#
# ~\anaconda3\envs\aiml\lib\site-packages\statsmodels\base\data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     699     klass = handle_data_class_factory(endog, exog)
#     700     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 701                  **kwargs)
#
# ~\anaconda3\envs\aiml\lib\site-packages\statsmodels\base\data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      86         self.const_idx = None
#      87         self.k_constant = 0
# ---> 88         self._handle_constant(hasconst)
#      89         self._check_integrity()
#      90         self._cache = {}
#
# ~\anaconda3\envs\aiml\lib\site-packages\statsmodels\base\data.py in _handle_constant(self, hasconst)
#     132             exog_max = np.max(self.exog, axis=0)
#     133             if not np.isfinite(exog_max).all():
# --> 134                 raise MissingDataError('exog contains inf or nans')
#     135             exog_min = np.min(self.exog, axis=0)
#     136             const_idx = np.where(exog_max == exog_min)[0].squeeze()
#
# MissingDataError: exog contains inf or nans

# %%
calc_vif(dataset[["etest_p","salary"]])

# %%
#from above two data to create model

# %% [markdown]
# # Independent sample-Unpaired T Test
# Different Group(Male,Female) but same contion(salary)

# %%
dataset=pd.read_csv("placement.csv")

# %%
dataset

# %%
dataset[dataset["gender"]=="F"]

# %%
dataset[dataset['gender']=="M"]

# %%
dataset[dataset['gender']=='M']['salary']

# %%
dataset[dataset['gender']=='F']['salary']

# %%
dataset[dataset['hsc_p']=='others']['salary']

# %%
dataset[dataset['hsc_p']=='central']['salary']

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
male = dataset[dataset['gender']=='M']['salary']
female = dataset[dataset['gender']=='F']['salary']
#print(male)
ttest_ind(male, female)

# %%
dataset=pd.read_csv("placement.csv")

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
others = dataset[dataset['hsc_p']=='O']['salary']
central = dataset[dataset['hsc_p']=='C']['salary']
#print(others)
ttest_ind(others, central)

# %%
dataset=pd.read_csv("placement.csv")

# %%
dataset

# %%
### Dependent Sample
#Same Group(Male) but Different Condition(ssc_p,hsc_p)

# %%
from scipy.stats import ttest_ind
#dataset=dataset.dropna()
male = dataset[dataset['gender']=='M']['ssc_p']
male1 = dataset[dataset['gender']=='M']['hsc_p']
#print(male)
ttest_ind(male, male1)

# %% [markdown]
# #same group(commerce) but different condition(mba_p,etest_p)

# %%
from scipy.stats import ttest_ind
#dataset=dataset.dropna()
commerce = dataset[dataset['gender']=='C']['mba_p']
commerce1 = dataset[dataset['gender']=='C']['etest_p']
#print(commerce)
ttest_ind(commerce, commerce1)

# %%
from scipy.stats import ttest_ind
#dataset=dataset.dropna()
science = dataset[dataset['gender']=='S']['mba_p']
science1 = dataset[dataset['gender']=='S']['etest_p']
#print(science)
ttest_ind(science, science1)

# %%
#Hypothesis Testing

# %%
#statement:Test whether ssc_p of male and Hsc_p of Male is same

# %%
#Null hypothesis=There is no similarity between 10th pass mark of male and 12th pass mark of male

# %%
from scipy.stats import ttest_rel
#dataset=dataset.dropna()
male = dataset[dataset['gender']=='M']['ssc_p']
male1 = dataset[dataset['gender']=='M']['hsc_p']
#print(male)
ttest_rel(male, male1)

# %% [markdown]
# # Reject Null hypothesis p<0.05
# #accept Null Hypothesis and Reject Alternate hypothesis
# ANAVO:Analysis of Variance

# %%
import scipy.stats as stats
stats.f_oneway(dataset['ssc_p'],dataset['hsc_p'],dataset['degree_p'])

# %%
#H0-there is no significant p<0.05
#H1-there is  significant difference these column

# %%
#TWO WAY ANAVO -the means of the first factor are equal,the means of the second factor are equal and there is no interaction between the two factor
#H0 population means of first factor (factorA) are equal.population means of second factor (factorB)are equal . -Null
#H1 Atleast one of the population means of the first factor (factorA) is different.and atleast one of the population means of the
#second factor (factorB)is different

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
#perform two way ANOVA 
model = ols('param ~ ssc_p + hsc_p + degree_p',data=dataset).fit()
anova_table = sm.stats.anova_1m(model,type=2)
print(anova_table)
